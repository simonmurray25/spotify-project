# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
#Source: https://github.com/guoguo12/billboard-charts/blob/master/README.md
import billboard
chart = billboard.ChartData('hot-100')
chart.title
# Out:
# 'Billboard Hot 100™'

# %%
#Source: https://github.com/guoguo12/billboard-charts/blob/master/README.md
print(chart)
# Out:
# hot-100 chart from 2024-01-13
# -----------------------------
# 1. 'Lovin On Me' by Jack Harlow
# 2. 'Cruel Summer' by Taylor Swift
# 3. 'Greedy' by Tate McRae
# 4. 'Paint The Town Red' by Doja Cat
# 5. 'I Remember Everything' by Zach Bryan Featuring Kacey Musgraves
# 6. 'Snooze' by SZA
# 7. 'Water' by Tyla
# 8. 'Last Night' by Morgan Wallen
# 9. 'Fast Car' by Luke Combs
# 10. 'Agora Hills' by Doja Cat
# 11. 'Thinkin' Bout Me' by Morgan Wallen
# 12. 'Lose Control' by Teddy Swims
# 13. 'Is It Over Now? (Taylor's Version) [From The Vault]' by Taylor Swift
# 14. 'Lil Boo Thang' by Paul Russell
# 15. 'Flowers' by Miley Cyrus
# 16. 'Rich Baby Daddy' by Drake Featuring Sexyy Red & SZA
# 17. 'FTCU' by Nicki Minaj
# 18. 'White Horse' by Chris Stapleton
# 19. 'Stick Season' by Noah Kahan
# 20. 'What Was I Made For?' by Billie Eilish
# 21. 'Vampire' by Olivia Rodrigo
# 22. 'Need A Favor' by Jelly Roll
# 23. 'Dance The Night' by Dua Lipa
# 24. 'Fukumean' by Gunna
# ...

# %%
#Source: https://github.com/guoguo12/billboard-charts/blob/master/tests/test_year_end_charts.py
chart_1970 = billboard.ChartData("hot-100-songs", year="1970")
dir(chart_1970.entries[0])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'artist',
#  'image',
#  'json',
#  'rank',
#  'title']

# %%
top_songs_df =  pd.DataFrame(columns=['Year','Title','Artist'])
for year_iter in range(2006, 2024):
    data = billboard.ChartData("hot-100-songs", year=year_iter)
    for song in range(1):
        title = data.entries[song].title
        artist = data.entries[song].artist
        top_songs_df.loc[len(top_songs_df.index)] = [year_iter, title, artist]  

top_songs_df
# Out:
#     Year                         Title                                  Artist
# 0   2006                       Bad Day                           Daniel Powter
# 1   2007                 Irreplaceable                                 Beyonce
# 2   2008                           Low               Flo Rida Featuring T-Pain
# 3   2009                 Boom Boom Pow                     The Black Eyed Peas
# 4   2010                       TiK ToK                                   Ke$ha
# 5   2011           Rolling In The Deep                                   Adele
# 6   2012  Somebody That I Used To Know                  Gotye Featuring Kimbra
# 7   2013                   Thrift Shop  Macklemore & Ryan Lewis Featuring Wanz
# 8   2014                         Happy                       Pharrell Williams
# 9   2015                  Uptown Funk!        Mark Ronson Featuring Bruno Mars
# 10  2016                 Love Yourself                           Justin Bieber
# ...

# %%
top_ten_songs_df =  pd.DataFrame(columns=['Year','Rank','Title','Artist'])
for year_iter in range(2006, 2024):
    data = billboard.ChartData("hot-100-songs", year=year_iter)
    for song in range(0,10):
        rank = data.entries[song].rank
        title = data.entries[song].title
        artist = data.entries[song].artist
        top_ten_songs_df.loc[len(top_ten_songs_df.index)] = [year_iter, rank, title, artist]  

top_ten_songs_df
# Out:
#      Year  Rank             Title                             Artist
# 0    2006     1           Bad Day                      Daniel Powter
# 1    2006     2       Temperature                          Sean Paul
# 2    2006     3       Promiscuous  Nelly Furtado Featuring Timbaland
# 3    2006     4  You're Beautiful                        James Blunt
# 4    2006     5    Hips Don't Lie      Shakira Featuring Wyclef Jean
# ..    ...   ...               ...                                ...
# 175  2023     6         Calm Down                Rema & Selena Gomez
# 176  2023     7       Die For You         The Weeknd & Ariana Grande
# 177  2023     8          Fast Car                         Luke Combs
# 178  2023     9            Snooze                                SZA
# 179  2023    10   I'm Good (Blue)          David Guetta & Bebe Rexha
#
# [180 rows x 4 columns]

# %%
from pathlib import Path  
filepath = Path('top_songs.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
top_songs_df.to_csv(filepath)

# %%
from pathlib import Path  
filepath = Path('top_ten_songs.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
top_ten_songs_df.to_csv(filepath)

# %%
top_hundred_songs_df =  pd.DataFrame(columns=['Year','Rank','Title','Artist'])
for year_iter in range(2006, 2024):
    data = billboard.ChartData("hot-100-songs", year=year_iter)
    for song in range(0,99):
        rank = data.entries[song].rank
        title = data.entries[song].title
        artist = data.entries[song].artist
        top_hundred_songs_df.loc[len(top_hundred_songs_df.index)] = [year_iter, rank, title, artist]  

top_hundred_songs_df
# Out:
#       Year  Rank                         Title  \
# 0     2006     1                       Bad Day
# 1     2006     2                   Temperature
# 2     2006     3                   Promiscuous
# 3     2006     4              You're Beautiful
# 4     2006     5                Hips Don't Lie
# ...    ...   ...                           ...
# 1777  2023    95              I Wrote The Book
# 1778  2023    96  Bzrp Music Sessions, Vol. 53
# 1779  2023    97                      Meltdown
# 1780  2023    98      Put It On Da Floor Again
# 1781  2023    99                   Bloody Mary
#
#                                  Artist
# 0                         Daniel Powter
# 1                             Sean Paul
# 2     Nelly Furtado Featuring Timbaland
# 3                           James Blunt
# 4         Shakira Featuring Wyclef Jean
# ...                                 ...
# 1777                      Morgan Wallen
# 1778                 Bizarrap & Shakira
# ...

# %%
from pathlib import Path  
filepath = Path('top_hun_songs.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
top_hundred_songs_df.to_csv(filepath)

# %%
categories_df =  pd.DataFrame(columns=['Category','Rank','Title','Artist'])
categories = ['greatest-of-all-time', 'pop','country', 'rock', 'alternative','r-b-hip-hop', 'dance-electronic', 'latin']
for cat in categories: 
    data = billboard.ChartData(f'{cat}-song')
    for song in range(0,40):
        rank = data.entries[song].rank
        title = data.entries[song].title
        artist = data.entries[song].artist
        categories_df.loc[len(categories_df.index)] = [cat, rank, title, artist]  

categories_df
# Out:
#                  Category  Rank                Title  \
# 0    greatest-of-all-time     1  I'll Be Missing You
# 1    greatest-of-all-time     2      The Boy Is Mine
# 2    greatest-of-all-time     3  Tossin' And Turnin'
# 3    greatest-of-all-time     4        Blurred Lines
# 4    greatest-of-all-time     5            Despacito
# ..                    ...   ...                  ...
# 315                 latin    36      Labios Mordidos
# 316                 latin    37      Sin Pagar Renta
# 317                 latin    38               Elvira
# 318                 latin    39                  CCC
# 319                 latin    40        No Es Mentira
#
#                                                 Artist
# 0               Puff Daddy & Faith Evans Featuring 112
# 1                                      Brandy & Monica
# 2                                          Bobby Lewis
# 3               Robin Thicke Featuring T.I. + Pharrell
# ...

# %%
from pathlib import Path  
filepath = Path('categories_top_40.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
categories_df.to_csv(filepath)
